# %%
import os
import json
import pandas as pd
import numpy as np
import json
from tqdm import tqdm

from shapely.geometry import Polygon
import glob
from PIL import Image
from pytesseract import pytesseract
from lxml import etree
import ast

from sklearn.model_selection import train_test_split
pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
f = open('labeling_result.json')
label_studio_data = json.load(f)
label_studio_data
# Out:
# [{'id': 13,
#   'annotations': [{'id': 13,
#     'completed_by': 1,
#     'result': [{'original_width': 879,
#       'original_height': 1295,
#       'image_rotation': 0,
#       'value': {'x': 1.0974041519163262,
#        'y': 0.37243947858473,
#        'width': 45.26792126654845,
#        'height': 62.56983240223464,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'oAG_FRxy1n',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 879,
#       'original_height': 1295,
#       'image_rotation': 0,
#       'value': {'x': 1.6461062278744891,
#        'y': 63.50093109869647,
#        'width': 44.71921919059029,
#        'height': 3.351955307262557,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'UmHbH1FUNa',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 879,
#       'original_height': 1295,
#       'image_rotation': 0,
#       'value': {'x': 0.8230531139372446,
#        'y': 70.94972067039106,
#        'width': 45.267921266548456,
#        'height': 25.512104283054,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': '7GG1E1X6lR',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 879,
#       'original_height': 1295,
#       'image_rotation': 0,
#       'value': {'x': 1.3717551898954077,
#        'y': 97.57914338919925,
#        'width': 44.99357022856937,
#        'height': 2.2346368715083855,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'N1OmdtNHBJ',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2025-11-01T05:56:53.742246Z',
#     'updated_at': '2025-11-01T05:56:53.742246Z',
#     'draft_created_at': '2025-11-01T05:50:24.983959Z',
#     'lead_time': 61.373,
#     'prediction': {},
#     'result_count': 4,
#     'unique_id': 'f7846078-9b66-4de4-9ac9-889680501888',
#     'import_id': None,
#     'last_action': None,
#     'task': 13,
#     'project': 3,
#     'updated_by': 1,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': 'e2a55870-13.png',
#   'drafts': [],
#   'predictions': [],
#   'data': {'image': '/data/upload/3/e2a55870-13.png'},
#   'meta': {},
#   'created_at': '2025-11-01T05:49:58.114445Z',
#   'updated_at': '2025-11-01T05:56:53.852456Z',
#   'inner_id': 1,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 3,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 14,
#   'annotations': [{'id': 14,
#     'completed_by': 1,
#     'result': [{'original_width': 863,
#       'original_height': 1301,
#       'image_rotation': 0,
#       'value': {'x': 0.8421965729526079,
#        'y': 0.37243947858473,
#        'width': 45.19788274845662,
#        'height': 25.139664804469273,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'yF0XwbTG4O',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 863,
#       'original_height': 1301,
#       'image_rotation': 0,
#       'value': {'x': 1.1229287639368104,
#        'y': 26.443202979515828,
#        'width': 45.197882748456614,
#        'height': 2.048417132216013,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 's9Xf0pMkbK',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 863,
#       'original_height': 1301,
#       'image_rotation': 0,
#       'value': {'x': 4.491715055747242,
#        'y': 32.774674115456236,
#        'width': 45.19788274845662,
#        'height': 26.44320297951584,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'B6U7XhXaBm',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 863,
#       'original_height': 1301,
#       'image_rotation': 0,
#       'value': {'x': 6.737572583620863,
#        'y': 59.77653631284916,
#        'width': 34.24932730007272,
#        'height': 2.2346368715083784,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'YeriXmp8mL',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2025-11-01T05:56:59.261115Z',
#     'updated_at': '2025-11-01T05:56:59.261115Z',
#     'draft_created_at': '2025-11-01T05:51:29.222883Z',
#     'lead_time': 20.046999999999997,
#     'prediction': {},
#     'result_count': 4,
#     'unique_id': 'e08530d5-a915-4c10-9077-c2c6406fe051',
#     'import_id': None,
#     'last_action': None,
#     'task': 14,
#     'project': 3,
#     'updated_by': 1,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '800bbe52-14.png',
#   'drafts': [],
#   'predictions': [],
#   'data': {'image': '/data/upload/3/800bbe52-14.png'},
#   'meta': {},
#   'created_at': '2025-11-01T05:49:58.114445Z',
#   'updated_at': '2025-11-01T05:56:59.380839Z',
#   'inner_id': 2,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 3,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 15,
#   'annotations': [{'id': 15,
#     'completed_by': 1,
#     'result': [{'original_width': 835,
#       'original_height': 1103,
#       'image_rotation': 0,
#       'value': {'x': 0.7379654099621985,
#        'y': 0.74487895716946,
#        'width': 46.9837977675933,
#        'height': 18.063314711359407,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': '-Ae9D7b3te',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 835,
#       'original_height': 1103,
#       'image_rotation': 0,
#       'value': {'x': 12.791400439344775,
#        'y': 19.925512104283055,
#        'width': 24.598846998739944,
#        'height': 2.420856610800744,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'JMp-A3vcwQ',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 835,
#       'original_height': 1103,
#       'image_rotation': 0,
#       'value': {'x': 51.1656017573791,
#        'y': 1.303538175046555,
#        'width': 45.507866947668894,
#        'height': 36.6852886405959,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'ICOfGUE4bx',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 835,
#       'original_height': 1103,
#       'image_rotation': 0,
#       'value': {'x': 56.57734809710189,
#        'y': 38.733705772811916,
#        'width': 34.19239732824852,
#        'height': 2.4208566108007474,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'FxKUQWBsRt',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 835,
#       'original_height': 1103,
#       'image_rotation': 0,
#       'value': {'x': 50.18164787742949,
#        'y': 65.17690875232775,
#        'width': 46.7378092976059,
#        'height': 19.180633147113596,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': '20xZ0-jPM8',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 835,
#       'original_height': 1103,
#       'image_rotation': 0,
#       'value': {'x': 60.75915208688767,
#        'y': 84.91620111731844,
#        'width': 26.56675475863915,
#        'height': 1.8621973929236475,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'mg3TcabTr9',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2025-11-01T05:57:03.707585Z',
#     'updated_at': '2025-11-01T05:57:03.707585Z',
#     'draft_created_at': '2025-11-01T05:51:50.846762Z',
#     'lead_time': 27.748,
#     'prediction': {},
#     'result_count': 6,
#     'unique_id': '99b7a217-1af6-4fe5-962f-7d41bf9ae349',
#     'import_id': None,
#     'last_action': None,
#     'task': 15,
#     'project': 3,
#     'updated_by': 1,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '13a1e382-25.png',
#   'drafts': [],
#   'predictions': [],
#   'data': {'image': '/data/upload/3/13a1e382-25.png'},
#   'meta': {},
#   'created_at': '2025-11-01T05:49:58.114445Z',
#   'updated_at': '2025-11-01T05:57:03.842947Z',
#   'inner_id': 3,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 3,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 16,
#   'annotations': [{'id': 16,
#     'completed_by': 1,
#     'result': [{'original_width': 821,
#       'original_height': 1239,
#       'image_rotation': 0,
#       'value': {'x': 1.4051538184119379,
#        'y': 1.675977653631285,
#        'width': 44.402860661817236,
#        'height': 17.31843575418994,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'URrPS-kPtM',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 821,
#       'original_height': 1239,
#       'image_rotation': 0,
#       'value': {'x': 3.091338400506263,
#        'y': 19.925512104283055,
#        'width': 42.43564531604052,
#        'height': 1.675977653631282,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'IwntlIP0Xa',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 821,
#       'original_height': 1239,
#       'image_rotation': 0,
#       'value': {'x': 0.8430922910471628,
#        'y': 43.947858472998135,
#        'width': 44.96492218918201,
#        'height': 17.31843575418994,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'yMvF5SA0KX',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 821,
#       'original_height': 1239,
#       'image_rotation': 0,
#       'value': {'x': 6.182676801012526,
#        'y': 62.38361266294227,
#        'width': 27.259984077191596,
#        'height': 1.1173184357541999,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'axhWNzOlsS',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 821,
#       'original_height': 1239,
#       'image_rotation': 0,
#       'value': {'x': 50.58553746282976,
#        'y': 1.675977653631285,
#        'width': 47.21316829864111,
#        'height': 43.38919925512104,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'djrPiUSbso',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 821,
#       'original_height': 1239,
#       'image_rotation': 0,
#       'value': {'x': 50.304506699147375,
#        'y': 46.55493482309125,
#        'width': 47.77522982600589,
#        'height': 1.6759776536312785,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'w1Kkhp75AX',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2025-11-01T05:57:08.614045Z',
#     'updated_at': '2025-11-01T05:57:08.614045Z',
#     'draft_created_at': '2025-11-01T05:52:18.372648Z',
#     'lead_time': 30.290000000000003,
#     'prediction': {},
#     'result_count': 6,
#     'unique_id': '26c53867-f929-4b28-93c1-7be57f11adab',
#     'import_id': None,
#     'last_action': None,
#     'task': 16,
#     'project': 3,
#     'updated_by': 1,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': 'e1253a39-26.png',
#   'drafts': [],
#   'predictions': [],
#   'data': {'image': '/data/upload/3/e1253a39-26.png'},
#   'meta': {},
#   'created_at': '2025-11-01T05:49:58.116969Z',
#   'updated_at': '2025-11-01T05:57:08.729699Z',
#   'inner_id': 4,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 3,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 17,
#   'annotations': [{'id': 17,
#     'completed_by': 1,
#     'result': [{'original_width': 840,
#       'original_height': 1232,
#       'image_rotation': 0,
#       'value': {'x': 51.34698944754811,
#        'y': 8.193668528864059,
#        'width': 43.97268777157045,
#        'height': 38.17504655493482,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'C1o0sRmIMa',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 840,
#       'original_height': 1232,
#       'image_rotation': 0,
#       'value': {'x': 54.07821229050279,
#        'y': 46.74115456238361,
#        'width': 39.87585350713843,
#        'height': 1.1173184357541857,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': '0p4I0HNJdM',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2025-11-01T05:57:13.725247Z',
#     'updated_at': '2025-11-01T05:57:13.725247Z',
#     'draft_created_at': '2025-11-01T05:52:48.733996Z',
#     'lead_time': 12.517,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '7b4db04e-9096-4a73-9c1d-c9e601a385ea',
#     'import_id': None,
#     'last_action': None,
#     'task': 17,
#     'project': 3,
#     'updated_by': 1,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '58cf7bf4-27.png',
#   'drafts': [],
#   'predictions': [],
#   'data': {'image': '/data/upload/3/58cf7bf4-27.png'},
#   'meta': {},
#   'created_at': '2025-11-01T05:49:58.116969Z',
#   'updated_at': '2025-11-01T05:57:13.854114Z',
#   'inner_id': 5,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 3,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 18,
#   'annotations': [{'id': 18,
#     'completed_by': 1,
#     'result': [{'original_width': 784,
#       'original_height': 1146,
#       'image_rotation': 0,
#       'value': {'x': 0,
#        'y': 27.560521415270017,
#        'width': 47.907878235092916,
#        'height': 29.050279329608934,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'jfQ8frzzXm',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 784,
#       'original_height': 1146,
#       'image_rotation': 0,
#       'value': {'x': 4.6274655113442025,
#        'y': 57.16945996275605,
#        'width': 39.197354919621475,
#        'height': 4.655493482309126,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'A-_wuaogcv',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2025-11-01T05:57:17.718109Z',
#     'updated_at': '2025-11-01T05:57:17.718109Z',
#     'draft_created_at': '2025-11-01T05:53:34.421624Z',
#     'lead_time': 13.702,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': 'fb7c0f08-116d-49db-b066-41f6192c9766',
#     'import_id': None,
#     'last_action': None,
#     'task': 18,
#     'project': 3,
#     'updated_by': 1,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '90d8d74d-32.png',
#   'drafts': [],
#   'predictions': [],
#   'data': {'image': '/data/upload/3/90d8d74d-32.png'},
#   'meta': {},
#   'created_at': '2025-11-01T05:49:58.116969Z',
#   'updated_at': '2025-11-01T05:57:17.829235Z',
#   'inner_id': 6,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 3,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 19,
#   'annotations': [{'id': 19,
#     'completed_by': 1,
#     'result': [{'original_width': 798,
#       'original_height': 1171,
#       'image_rotation': 0,
#       'value': {'x': 4.098934487055628,
#        'y': 1.48975791433892,
#        'width': 41.8091317679674,
#        'height': 17.504655493482307,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'HxujTlFqBc',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 798,
#       'original_height': 1171,
#       'image_rotation': 0,
#       'value': {'x': 0.8197868974111255,
#        'y': 19.180633147113593,
#        'width': 46.181328554160075,
#        'height': 2.234636871508382,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'jFZfG-afC6',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2025-11-01T05:57:22.264134Z',
#     'updated_at': '2025-11-01T05:57:22.264134Z',
#     'draft_created_at': '2025-11-01T05:53:13.037705Z',
#     'lead_time': 42.388000000000005,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '984ee2b1-43b4-47be-9681-1a122f224623',
#     'import_id': None,
#     'last_action': None,
#     'task': 19,
#     'project': 3,
#     'updated_by': 1,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '3b6c5c88-41.png',
#   'drafts': [],
#   'predictions': [],
#   'data': {'image': '/data/upload/3/3b6c5c88-41.png'},
#   'meta': {},
#   'created_at': '2025-11-01T05:49:58.117507Z',
#   'updated_at': '2025-11-01T05:57:22.377610Z',
#   'inner_id': 7,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 3,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 20,
#   'annotations': [{'id': 20,
#     'completed_by': 1,
#     'result': [{'original_width': 832,
#       'original_height': 1227,
#       'image_rotation': 0,
#       'value': {'x': 15.928502363558227,
#        'y': 0.5586592178770949,
#        'width': 72.22751933820369,
#        'height': 47.113594040968344,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'v4VDEj_PD7',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 832,
#       'original_height': 1227,
#       'image_rotation': 0,
#       'value': {'x': 38.997367855608076,
#        'y': 47.8584729981378,
#        'width': 26.089788354104,
#        'height': 2.2346368715083784,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'dBu4BSuUO1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2025-11-01T05:57:27.325643Z',
#     'updated_at': '2025-11-01T05:57:27.325643Z',
#     'draft_created_at': '2025-11-01T05:54:24.679010Z',
#     'lead_time': 14.045,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '404d490a-86f2-421a-b203-4a60fa05bfa2',
#     'import_id': None,
#     'last_action': None,
#     'task': 20,
#     'project': 3,
#     'updated_by': 1,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '3ea3794d-42.png',
#   'drafts': [],
#   'predictions': [],
#   'data': {'image': '/data/upload/3/3ea3794d-42.png'},
#   'meta': {},
#   'created_at': '2025-11-01T05:49:58.117507Z',
#   'updated_at': '2025-11-01T05:57:27.453829Z',
#   'inner_id': 8,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 3,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 21,
#   'annotations': [{'id': 21,
#     'completed_by': 1,
#     'result': [{'original_width': 826,
#       'original_height': 1174,
#       'image_rotation': 0,
#       'value': {'x': 12.439749121881496,
#        'y': 18.994413407821227,
#        'width': 74.37381921805745,
#        'height': 29.05027932960894,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'cBJDLk5PYQ',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 826,
#       'original_height': 1174,
#       'image_rotation': 0,
#       'value': {'x': 27.261577862846682,
#        'y': 48.23091247672253,
#        'width': 43.40678416996947,
#        'height': 1.6759776536312856,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': '9YlII7eD93',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2025-11-01T05:57:30.911249Z',
#     'updated_at': '2025-11-01T05:57:30.911249Z',
#     'draft_created_at': '2025-11-01T05:54:06.034491Z',
#     'lead_time': 23.182,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '6f31ea40-30ed-4fe7-b5fb-6a4ffdeeb00e',
#     'import_id': None,
#     'last_action': None,
#     'task': 21,
#     'project': 3,
#     'updated_by': 1,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': 'e3d40692-44.png',
#   'drafts': [],
#   'predictions': [],
#   'data': {'image': '/data/upload/3/e3d40692-44.png'},
#   'meta': {},
#   'created_at': '2025-11-01T05:49:58.117507Z',
#   'updated_at': '2025-11-01T05:57:31.038471Z',
#   'inner_id': 9,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 3,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 22,
#   'annotations': [{'id': 22,
#     'completed_by': 1,
#     'result': [{'original_width': 928,
#       'original_height': 1211,
#       'image_rotation': 0,
#       'value': {'x': 4.131148462081808,
#        'y': 48.78957169459962,
#        'width': 38.39537982405445,
#        'height': 46.927374301675975,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'IDRlSOYI28',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 928,
#       'original_height': 1211,
#       'image_rotation': 0,
#       'value': {'x': 7.290261991909073,
#        'y': 97.39292364990689,
#        'width': 38.881397290181724,
#        'height': 2.6070763500931093,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'mmQmMSJbmd',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2025-11-01T05:57:33.689608Z',
#     'updated_at': '2025-11-01T05:57:33.691615Z',
#     'draft_created_at': '2025-11-01T05:54:59.373686Z',
#     'lead_time': 10.707,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '33ef75a7-8616-4f94-8a4b-d3f4a018f1a4',
#     'import_id': None,
#     'last_action': None,
#     'task': 22,
#     'project': 3,
#     'updated_by': 1,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': 'cdd9c1fd-49.png',
#   'drafts': [],
#   'predictions': [],
#   'data': {'image': '/data/upload/3/cdd9c1fd-49.png'},
#   'meta': {},
#   'created_at': '2025-11-01T05:49:58.117507Z',
#   'updated_at': '2025-11-01T05:57:33.810321Z',
#   'inner_id': 10,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 3,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 23,
#   'annotations': [{'id': 23,
#     'completed_by': 1,
#     'result': [{'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 9.2130358321005,
#        'y': 55.121042830540034,
#        'width': 39.74766887563358,
#        'height': 17.690875232774673,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'yocrQU1NQ8',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 12.8982501649407,
#        'y': 73.18435754189943,
#        'width': 32.377240209953186,
#        'height': 1.489757914338938,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'JGANuD1eal',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2025-11-01T05:57:36.802627Z',
#     'updated_at': '2025-11-01T05:57:36.802627Z',
#     'draft_created_at': '2025-11-01T05:55:09.359062Z',
#     'lead_time': 9.271,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': 'c699bd98-a4f9-4149-9e9b-e1070d251600',
#     'import_id': None,
#     'last_action': None,
#     'task': 23,
#     'project': 3,
#     'updated_by': 1,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '472b3c8d-66.png',
#   'drafts': [],
#   'predictions': [],
#   'data': {'image': '/data/upload/3/472b3c8d-66.png'},
#   'meta': {},
#   'created_at': '2025-11-01T05:49:58.117507Z',
#   'updated_at': '2025-11-01T05:57:36.937500Z',
#   'inner_id': 11,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 3,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 24,
#   'annotations': [{'id': 24,
#     'completed_by': 1,
#     'result': [{'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 14.740857331360798,
#        'y': 55.121042830540034,
#        'width': 31.061092233938826,
#        'height': 24.20856610800746,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'IR5rbbvVlb',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 17.373153283389513,
#        'y': 80.26070763500931,
#        'width': 25.533270734678524,
#        'height': 1.6759776536312927,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'jjcP_88p8O',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2025-11-01T05:57:39.535912Z',
#     'updated_at': '2025-11-01T05:57:39.535912Z',
#     'draft_created_at': '2025-11-01T05:55:20.497844Z',
#     'lead_time': 16.076,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '2d5fba75-b352-4730-95ac-ff943cd953f2',
#     'import_id': None,
#     'last_action': None,
#     'task': 24,
#     'project': 3,
#     'updated_by': 1,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': 'c474b043-67.png',
#   'drafts': [],
#   'predictions': [],
#   'data': {'image': '/data/upload/3/c474b043-67.png'},
#   'meta': {},
#   'created_at': '2025-11-01T05:49:58.117507Z',
#   'updated_at': '2025-11-01T05:57:39.672035Z',
#   'inner_id': 12,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 3,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 25,
#   'annotations': [{'id': 25,
#     'completed_by': 1,
#     'result': [{'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 26.05972992508427,
#        'y': 11.1731843575419,
#        'width': 47.38132713651686,
#        'height': 7.448789571694601,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'p0_o1Yk0_L',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 39.22120968522784,
#        'y': 19.553072625698324,
#        'width': 21.32159721143259,
#        'height': 1.3035381750465547,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'jGdLqm6Ys1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 25.533270734678524,
#        'y': 30.726256983240223,
#        'width': 47.381327136516845,
#        'height': 7.262569832402232,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'KxJSSwUdHx',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 39.747668875633586,
#        'y': 39.29236499068901,
#        'width': 20.26867883062109,
#        'height': 1.3035381750465618,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'zlFBgTk7lH',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 25.006811544272782,
#        'y': 54.37616387337057,
#        'width': 49.7503934933427,
#        'height': 8.37988826815642,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': '30pjVwpVzh',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 38.95798009002497,
#        'y': 63.50093109869647,
#        'width': 21.05836761622971,
#        'height': 2.4208566108007403,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'chVkBZT650',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 21.848056401838324,
#        'y': 76.16387337057728,
#        'width': 55.014985397400125,
#        'height': 6.890130353817511,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'pS5mH-Ski0',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 39.48443928043071,
#        'y': 83.79888268156425,
#        'width': 21.321597211432575,
#        'height': 0.9310986964618309,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'elIXbIYef1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2025-11-01T05:57:42.334075Z',
#     'updated_at': '2025-11-01T05:57:42.334075Z',
#     'draft_created_at': '2025-11-01T05:55:41.322122Z',
#     'lead_time': 30.159000000000002,
#     'prediction': {},
#     'result_count': 8,
#     'unique_id': '31d9f4bb-28e0-4ac0-92d6-baf8b3f58b27',
#     'import_id': None,
#     'last_action': None,
#     'task': 25,
#     'project': 3,
#     'updated_by': 1,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '59155038-100.png',
#   'drafts': [],
#   'predictions': [],
#   'data': {'image': '/data/upload/3/59155038-100.png'},
#   'meta': {},
#   'created_at': '2025-11-01T05:49:58.117507Z',
#   'updated_at': '2025-11-01T05:57:42.491229Z',
#   'inner_id': 13,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 3,
#   'updated_by': 1,
#   'comment_authors': []},
#  {'id': 26,
#   'annotations': [{'id': 26,
#     'completed_by': 1,
#     'result': [{'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 21.058367616229713,
#        'y': 17.877094972067038,
#        'width': 57.384051754225965,
#        'height': 7.821229050279332,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': '-Ph6vbbj6D',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 39.22120968522784,
#        'y': 26.629422718808193,
#        'width': 22.63774518744694,
#        'height': 2.4208566108007474,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'DaWA381uL4',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 24.743581949069913,
#        'y': 54.7486033519553,
#        'width': 51.59300065976279,
#        'height': 7.448789571694604,
#        'rotation': 0,
#        'rectanglelabels': ['image']},
#       'id': 'Wmag6SX0W4',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 1654,
#       'original_height': 2338,
#       'image_rotation': 0,
#       'value': {'x': 39.747668875633586,
#        'y': 62.94227188081937,
#        'width': 20.53190842582397,
#        'height': 1.6759776536312856,
#        'rotation': 0,
#        'rectanglelabels': ['caption-image']},
#       'id': 'FpkFd4u8Yr',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2025-11-01T05:57:46.122186Z',
#     'updated_at': '2025-11-01T05:57:46.124677Z',
#     'draft_created_at': '2025-11-01T05:56:14.836600Z',
#     'lead_time': 18.03,
#     'prediction': {},
#     'result_count': 4,
#     'unique_id': 'cd0375bb-adce-487b-947b-60ad12801cce',
#     'import_id': None,
#     'last_action': None,
#     'task': 26,
#     'project': 3,
#     'updated_by': 1,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': None}],
#   'file_upload': '1b0f92f5-101.png',
#   'drafts': [],
#   'predictions': [],
#   'data': {'image': '/data/upload/3/1b0f92f5-101.png'},
#   'meta': {},
#   'created_at': '2025-11-01T05:49:58.117507Z',
#   'updated_at': '2025-11-01T05:57:46.243096Z',
#   'inner_id': 14,
#   'total_annotations': 1,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 3,
#   'updated_by': 1,
#   'comment_authors': []}]

# %%
os.makedirs('./data/layoutlmv3_hocr_output', exist_ok=True)

# %%
def calculate_iou(box_1, box_2):
    poly_1 = Polygon(box_1)
    poly_2 = Polygon(box_2)
    # print(poly_1,poly_2)
    # iou = poly_1.intersection(poly_2).area / poly_1.union(poly_2).area
    iou = poly_1.intersection(poly_2).area
    min_area = min(poly_1.area,poly_2.area)
    return iou/min_area
    
    
def hocr_to_dataframe(fp):
    """Convert .hocr file to dataframe of words, coords, confidence."""
    doc = etree.parse(fp)
    words, wordConf, coords_list = [], [], []

    for path in doc.xpath('//*'):
        if 'ocrx_word' in path.values():
            title = path.attrib.get('title', '')
            # Example: title="bbox 36 148 215 173; x_wconf 95"
            parts = title.split(';')
            bbox_part = parts[0].replace('bbox', '').strip().split(' ')
            word_coord = list(map(int, bbox_part))  # [x1, y1, x2, y2]
            conf = 0
            if len(parts) > 1 and 'x_wconf' in parts[1]:
                conf = int(parts[1].split('x_wconf')[-1].strip())
            wordConf.append(conf)
            coords_list.append(word_coord)
            words.append(path.text if path.text else '-')

    return pd.DataFrame({'word': words, 'coords': coords_list, 'confidence': wordConf})

# %%
document_data = dict()
document_data['file_name'] = []
document_data['labelled_bbox']= []

for i in range(len(label_studio_data)):
    row = label_studio_data[i]
    file_name = os.path.basename(row['data']['image'])
    label_list, labels, bboxes = [], [], []

    for label_ in row['annotations'][0]['result']:
        label_value = label_['value']
        x, y, w, h = label_value['x'], label_value['y'], label_value['width'], label_value['height']
        original_w , original_h = label_['original_width'], label_['original_height']

        x1 = int((x * original_w) / 100)
        y1 = int((y * original_h) / 100)
        x2 = x1 + int(original_w*w / 100)
        y2 = y1 + int(original_h*h / 100)
        
        label = label_value['rectanglelabels']
        label_list.append((label, (x1,y1,x2,y2), original_h, original_w))
        
    document_data['file_name'].append(file_name)    
    document_data['labelled_bbox'].append(label_list)        

custom_dataset = pd.DataFrame(document_data)

# %%
custom_dataset
# Out:
#            file_name                                      labelled_bbox
# 0    e2a55870-13.png  [([image], (9, 4, 406, 814), 1295, 879), ([cap...
# 1    800bbe52-14.png  [([image], (7, 4, 397, 331), 1301, 863), ([cap...
# 2    13a1e382-25.png  [([image], (6, 8, 398, 207), 1103, 835), ([cap...
# 3    e1253a39-26.png  [([image], (11, 20, 375, 234), 1239, 821), ([c...
# 4    58cf7bf4-27.png  [([image], (431, 100, 800, 570), 1232, 840), (...
# 5    90d8d74d-32.png  [([image], (0, 315, 375, 647), 1146, 784), ([c...
# 6    3b6c5c88-41.png  [([image], (32, 17, 365, 221), 1171, 798), ([c...
# 7    3ea3794d-42.png  [([image], (132, 6, 732, 584), 1227, 832), ([c...
# 8    e3d40692-44.png  [([image], (102, 222, 716, 563), 1174, 826), (...
# 9    cdd9c1fd-49.png  [([image], (38, 590, 394, 1158), 1211, 928), (...
# 10   472b3c8d-66.png  [([image], (152, 1288, 809, 1701), 2338, 1654)...
# 11   c474b043-67.png  [([image], (243, 1288, 756, 1853), 2338, 1654)...
# 12  59155038-100.png  [([image], (431, 261, 1214, 435), 2338, 1654),...
# 13  1b0f92f5-101.png  [([image], (348, 417, 1297, 599), 2338, 1654),...

# %%
label2id = {"image": 0, "caption-image": 1}
id2label = {v:k for k, v in label2id.items()}

# %%
# %%time

final_list = []

for i in tqdm(custom_dataset.iterrows(), total=custom_dataset.shape[0]):
    custom_label_text = {}
    word_list, ner_tags_list, bboxes_list = [], [], []

    file_name = i[1]['file_name']
    for image in glob.glob('./data/dataset/*.png'):
        if os.path.basename(image) == file_name:
            custom_label_text['id'] = i[0]
            custom_label_text['file_name'] = file_name
            label_coord_list = i[1]['labelled_bbox']

            # ✅ Generate HOCR file (fixed extension)
            base_name = os.path.join('./data/layoutlmv3_hocr_output', os.path.splitext(file_name)[0])
            pytesseract.run_tesseract(image, base_name, extension='hocr', lang=None, config="hocr")

            hocr_file = base_name + '.hocr'
            if not os.path.exists(hocr_file):
                raise FileNotFoundError(f"Tesseract failed to create {hocr_file}")

            hocr_df = hocr_to_dataframe(hocr_file)

            for label_coord in label_coord_list:
                (x1, y1, x2, y2) = label_coord[1]
                box1 = [[x1, y1], [x2, y1], [x2, y2], [x1, y2]]
                label = label_coord[0][0]

                for _, word in hocr_df.iterrows():
                    coords = word['coords']
                    (x1df, y1df, x2df, y2df) = coords
                    box2 = [[x1df, y1df], [x2df, y1df], [x2df, y2df], [x1df, y2df]]
                    overlap_perc = calculate_iou(box1, box2)
                    if overlap_perc > 0.80 and word['word'] != '-':
                        word_list.append(word['word'])
                        bboxes_list.append(coords)
                        ner_tags_list.append(label2id[label])

            custom_label_text['tokens'] = word_list
            custom_label_text['bboxes'] = bboxes_list
            custom_label_text['ner_tags'] = ner_tags_list
            final_list.append(custom_label_text)
# Out:
# 100%|██████████| 14/14 [00:41<00:00,  2.93s/it]
# CPU times: total: 4.23 s
# Wall time: 41.1 s

# %%
# with open('test.json','w') as file:
#     json.dump(final_list, file, indent=2)

# %%
train, test = train_test_split(final_list, random_state=21, test_size=0.2)

for detail  in final_list:
    with open('final_list_text.txt', 'a') as f:
        f.write(str(detail))
        f.write('\n')
        
for detail  in train:
    with open('train.txt', 'a') as f:
        f.write(str(detail))
        f.write('\n')

# %%
for detail in test:
    with open('test.txt', 'a') as f:
        f.write(str(detail))
        f.write('\n')
