# %%
from ultralytics import YOLO

# %%
model = YOLO("../yolo/models/kfold_result/kfold_training/fold_4/weights/best.pt")
results = model.val(data="data.yaml", split="val", imgsz=640, save=True)
# Out:
# Ultralytics 8.3.223  Python-3.13.5 torch-2.9.0+cpu CPU (11th Gen Intel Core i7-11370H @ 3.30GHz)
# Model summary (fused): 72 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access  (ping: 0.10.2 ms, read: 79.943.2 MB/s, size: 783.5 KB)
# val: Scanning D:\Research-Methodology\yolo\preprocess_and_training\split10\test\labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 30/30 28.3Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 7.5s14.6s
#                    all         30        127       0.83       0.91       0.94       0.61
#                Caption         29         44      0.738      0.886       0.92      0.537
#             PageNumber         23         36      0.794      0.861      0.907      0.419
#                Picture         30         47      0.958      0.982      0.994      0.875
# Speed: 4.1ms preprocess, 201.5ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to D:\Research-Methodology\runs\detect\val3
